# %% [markdown]
# #Task 2 - Superstore_USA
# 1. load this data in sql and in pandas with a relation in sql
# 2. while loading this data you dont have to create a table manually you can use any automated approach to create a table and
#    load a data in bulk in table
# 3. Find out how return that we have recived and with a product id
# 4. try  to join order and return data both in sql and pandas
# 5. Try to find out how many unique customer that we have
# 6. try to find out in how many regions we are selling a product and who is a manager for a respective region
# 7. find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode
#    with respect to dataset
# 8. Create a new coulmn and try to find our a diffrence between order date and shipment date
# 9. base on question number 8 find out for which order id we have shipment duration more than 10 days
# 10. Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as
#     well
# 11. Gorup by region and find out which region is more profitable
# 12. Try to find out overalll in which country we are giving more didscount
# 13. Give me a list of unique postal code
# 14. which customer segement is more profitalble find it out .
# 15. try to find out the 10th most loss making product catagory .
# 16. Try to find out 10 top  product with highest margins

# %%
import pandas as pd
import mysql.connector as mysql
import logging
from mysql.connector import Error
import pymysql
import os
from sqlalchemy import create_engine

# %%
#Task2- qstn1-Database creation

def database_creation():
    try:
        mydb = mysql.connect(host = "localhost" , user ="root" , passwd = "Hannah_0027" )
        if mydb.is_connected():
            cursor = mydb.cursor()
            cursor.execute("CREATE DATABASE if not exists store_usa")
            print("Database is created")
    except Exception as e:
         print("Error while connecting to MySQL...", e)
database_creation()
# Out:
# Database is created

# %%
# Qstn 2-Create table and insert values into the table[while creting a table in mysql dont use manual approach to create it  ,always use a automation to create a table in mysql]

engine = create_engine('mysql+pymysql://root:Hannah_0027@localhost/store_usa')
order = pd.read_csv(r'C:\Users\ASUS\Desktop\code\data science\task\task\Superstore_USA.csv')

order.to_sql('super_store_usa', con=engine)

# %%
order
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
order.dtypes
# Out:
# Row ID                    int64
# Order Priority           object
# Discount                float64
# Unit Price              float64
# Shipping Cost           float64
# Customer ID               int64
# Customer Name            object
# Ship Mode                object
# Customer Segment         object
# Product Category         object
# Product Sub-Category     object
# Product Container        object
# Product Name             object
# Product Base Margin     float64
# Region                   object
# State or Province        object
# City                     object
# Postal Code               int64
# Order Date               object
# Ship Date                object
# Profit                  float64
# Quantity ordered new      int64
# Sales                   float64
# Order ID                  int64
# dtype: object

# %%
order.dtypes
# Out:
# Row ID                    int64
# Order Priority           object
# Discount                float64
# Unit Price              float64
# Shipping Cost           float64
# Customer ID               int64
# Customer Name            object
# Ship Mode                object
# Customer Segment         object
# Product Category         object
# Product Sub-Category     object
# Product Container        object
# Product Name             object
# Product Base Margin     float64
# Region                   object
# State or Province        object
# City                     object
# Postal Code               int64
# Order Date               object
# Ship Date                object
# Profit                  float64
# Quantity ordered new      int64
# Sales                   float64
# Order ID                  int64
# dtype: object

# %%
# Qstn3- Find out how return that we have recived and with a product id 

a = pd.ExcelFile(r'C:\Users\ASUS\Desktop\code\data science\task\task\Superstore_USA.xlsx')
returns = pd.read_excel(a, 'Returns',names = ["Order ID","Status"])
users = pd.read_excel(a, 'Users')

# %%
returns
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
order_returns = pd.merge(order, returns)

# %%
merged_table= pd.DataFrame(order_returns)

# %%
merged_table
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
merged_table[(merged_table['Status']=='Returned')]['Order ID']
# Out:
# 0      9895
# 1     13959
# 2     13959
# 3     36038
# 4     39490
#       ...
# 93     7107
# 94     7107
# 95    42823
# 96    13638
# 97    47109
# Name: Order ID, Length: 98, dtype: int64

# %%
 #Qstn 4 -Try  to join order and return data both in sql and pandas
    
pd.merge(order, returns)

#select * from returns JOIN super_store_usa ON super_store_usa.Order ID=returns.order ID;
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
#Qstn 5 -Try to find out how many unique customer that we have 

total = order['Customer ID'].unique()
print(" Number of unique customers:", len(total))
# Out:
#  Number of unique customers: 2703

# %%
# sql guerry for qstn 5
cursor = mydb.cursor()
cursor.execute("select count(distinct Customer ID) from super_store_usa;") 
print(cursor.fetchall())
cursor.close()

# %%
#Qstn 6 -Try to find out in how many regions we are selling a product and who is a manager for a respective region 

users
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
len(order['Region'].unique())
# Out:
# 4

# %%
# Qstn 6 -Find out how many different shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset

shipment = order['Ship Mode']

# %%
type(shipment)
# Out:
# pandas.core.series.Series

# %%
s = pd.Series(shipment).value_counts()
print("Different shipment modes are : ",s)
# Out:
# Different shipment modes are :  Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
ship = pd.DataFrame(s)

# %%
shipment_total = pd.Series(shipment).count()
print(shipment_total)
# Out:
# 9426

# %%
((ship [['Ship Mode']])/shipment_total)*100
# Out:
#                 Ship Mode
# Regular Air     74.644600
# Delivery Truck  13.611288
# Express Air     11.744112

# %%
order
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
order['Ship Date'] = pd.to_datetime(df['Ship Date'])
order['Order Date'] = pd.to_datetime(df['Order Date'])
order.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                           int64
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
#Qstn 8 - Create a new coulmn and try to find our a diffrence between order date and shipment date

order["difference_date"] =  order['Ship Date'] - order['Order Date'] 
order["difference_date"]
# Out:
# 0        2 days
# 1       31 days
# 2        1 days
# 3        1 days
# 4        0 days
#          ...
# 9421     1 days
# 9422     0 days
# 9423   -86 days
# 9424    92 days
# 9425   -86 days
# Name: difference_date, Length: 9426, dtype: timedelta64[ns]

# %%
order[(order['difference_date'].dt.components['days']>10)]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1      20847           High      0.01        2.84           0.93            3
# 5      23597         Medium      0.09       55.48          14.30            3
# 6      25549            Low      0.08      120.97          26.30            3
# 16     22241       Critical      0.06       15.57           1.39           10
# 24     18181       Critical      0.00        4.42           4.99           15
# ...      ...            ...       ...         ...            ...          ...
# 9405   21952  Not Specified      0.05       10.91           2.99         3397
# 9406   22599       Critical      0.01      177.98           0.99         3398
# 9415   26043  Not Specified      0.06       30.98           6.50         3400
# 9419   24912         Medium      0.05       35.99           1.25         3400
# 9424   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
#Qstn 9 - Based on Question number 8, find out for which order id we have shipment duration more than 10 day

order[(order['difference_date'].dt.components['days']>15)]['Order ID']
# Out:
# 1       88522
# 5       88524
# 6       88526
# 16      90195
# 24      86837
#         ...
# 9405    87547
# 9406    87538
# 9415    87540
# 9419    87549
# 9424    87530
# Name: Order ID, Length: 2895, dtype: int64

# %%
# Out:
# 1       20847
# 5       23597
# 6       25549
# 16      22241
# 24      18181
#         ...
# 9405    21952
# 9406    22599
# 9415    26043
# 9419    24912
# 9424    25914
# Name: Row ID, Length: 2897, dtype: int64

# %%
order.dtypes
# Out:
# Row ID                            int64
# Order Priority                   object
# Discount                        float64
# Unit Price                      float64
# Shipping Cost                   float64
# Customer ID                       int64
# Customer Name                    object
# Ship Mode                        object
# Customer Segment                 object
# Product Category                 object
# Product Sub-Category             object
# Product Container                object
# Product Name                     object
# Product Base Margin             float64
# Region                            int64
# State or Province                object
# City                             object
# Postal Code                       int64
# Order Date               datetime64[ns]
# Ship Date                datetime64[ns]
# Profit                          float64
# Quantity ordered new              int64
# Sales                           float64
# ...

# %%
order_returns = pd.merge(order, returns)
order_returns
order_returns.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date',
#        'Status'],
#       dtype='object')

# %%
#Qstns 10 - Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 


order_returns[(order_returns['difference_date'].dt.components['days']>15)]
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 8     5257            Low      0.09      550.98          64.59          349
# 9     6643       Critical      0.02        5.98           5.46          349
# 10     979         Medium      0.01      280.98          57.00          478
# 11     980         Medium      0.03        6.48           5.94          478
# 28    7966           High      0.05        7.99           5.03         1060
# 31    3435       Critical      0.03        5.34           5.63         1106
# 43    5883            Low      0.00        9.98          12.52         1228
# 51    5252       Critical      0.08       26.64           5.30         1314
# 52    5253       Critical      0.00        9.99           4.78         1314
# ...

# %%
#Qstn 11 - Group by region and find out which region is most profitable 
order.groupby(['Region'])['Profit'].aggregate('count').reset_index().sort_values("Profit",ascending = True).max()
# Out:
# Region       0
# Profit    9426
# dtype: int64

# %%
#12. Try to find out overall in which country we are giving more discount 
[order[order['Discount']>0.1]['Region']]
# Out:
# [5990    0
#  5991    0
#  6000    0
#  8649    0
#  8661    0
#  Name: Region, dtype: int64]

# %%
order
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#QSTN 13- Give me a list of unique postal code 
order['Postal Code'].unique()
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %%
#Qstn 14 - Which customer segement is more profitable find it out . 
order.groupby(['Customer Segment'])['Profit'].aggregate('count')
# Out:
# Customer Segment
# Consumer          1894
# Corporate         3375
# Home Office       2316
# Small Business    1841
# Name: Profit, dtype: int64

# %%
#Qstn 15- try to find out the 10th most loss making product catagory . 
order[order['Profit']<0].reset_index().sort_values('Profit', ascending = True).head(10)
# Out:
#       index  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 2291   4659   18306         Medium      0.08      175.99           4.99
# 2121   4338   20972            Low      0.01       24.95           2.99
# 3811   7800   23213            Low      0.09     6783.02          24.49
# 2381   4844   21284       Critical      0.04      880.98          44.55
# 2660   5402   24076         Medium      0.04     6783.02          24.49
# 2664   5409   22942           High      0.05     3502.14           8.73
# 3771   7725   21048  Not Specified      0.06     6783.02          24.49
# 1061   2191   21575  Not Specified      0.05     3499.99          24.49
# 1977   4068   21917           High      0.06     3502.14           8.73
# 2387   4857   24251           High      0.05     3502.14           8.73
#
#       Customer ID         Customer Name       Ship Mode Customer Segment  ...  \
# 2291         1738          Dean Solomon     Regular Air        Corporate  ...
# ...

# %%
#Qstn 16 - Try to find out 10 top  product with highest margins 
order.sort_values(['Product Base Margin'])['Product Name'].head(10)
# Out:
# 2431              GBC DocuBind 200 Manual Binding Machine
# 8248       Peel & Seel� Recycled Catalog Envelopes, Brown
# 1515       Peel & Seel� Recycled Catalog Envelopes, Brown
# 5050       Peel & Seel� Recycled Catalog Envelopes, Brown
# 413                                           Accessory31
# 5034                          Prang Dustless Chalk Sticks
# 8308         Staples Brown Kraft Recycled Clasp Envelopes
# 8311     Storex DuraTech Recycled Plastic Frosted Binders
# 8318                                          Accessory31
# 1553    Adams Telephone Message Book w/Frequently-Call...
# Name: Product Name, dtype: object
